# %% [markdown]
# # Business Analyst Project

# %%
# pip install Faker

# %% [markdown]
# ## Creating and inserting data

# %%
from faker import Faker
import pandas as pd
import random

# %%
fake = Faker()

# %%
# Generate sample data for products, customers, sales, orders, and suppliers
products = [{'product_id': i, 'product_name': fake.word(), 'price': fake.random_number(2)} for i in range(1, 101)]
customers = [{'customer_id': i, 'customer_name': fake.name(), 'email': fake.email(), 'gender': fake.random_element(elements=('M', 'F'))} for i in range(1, 51)]
sales = [{'sale_id': i, 'product_id': fake.random_int(min=1, max=100), 'customer_id': fake.random_int(min=1, max=50), 'quantity': fake.random_int(min=1, max=10), 'sale_amount': fake.random_number(4)} for i in range(1, 1001)]
orders = [{'order_id': i, 'customer_id': fake.random_int(min=1, max=50), 'order_date': fake.date_time_between(start_date='-1y', end_date='now'), 'total_amount': fake.random_number(4), 'status': fake.random_element(elements=('pending', 'shipped', 'delivered'))} for i in range(1, 501)]
suppliers = [{'supplier_id': i, 'supplier_name': fake.company(), 'contact_info': ''.join(random.choices('6789', k=10)), 'product_id': fake.random_int(min=1, max=100)} for i in range(1, 21)]

# Add product_id to customers table
for customer in customers:
    customer['product_id'] = random.choice([product['product_id'] for product in products])

# Ensure product_id in suppliers corresponds to an existing product_id in Products
for supplier in suppliers:
    supplier['product_id'] = random.choice([product['product_id'] for product in products])

# Ensure product_id in sales corresponds to an existing product_id in Products
for sale in sales:
    sale['product_id'] = random.choice([product['product_id'] for product in products])

# Ensure product_id in orders corresponds to an existing product_id in Products
for order in orders:
    order['product_id'] = random.choice([product['product_id'] for product in products])

# %%
products_df = pd.DataFrame(products)
customers_df = pd.DataFrame(customers)
sales_df = pd.DataFrame(sales)
orders_df = pd.DataFrame(orders)
suppliers_df = pd.DataFrame(suppliers)

# %%
# prducts_df.isnull().sum()

# %%
# suppliers_df.isnull().sum()

# %%
# sales_df.isnull().sum()

# %%
# orders_df.isnull().sum()

# %%
# customers_df.isnull().sum()

# %% [markdown]
# ## Convert data into CSV file

# %%
products_df.to_csv('products.csv', index=False)

# %%
customers_df.to_csv('customers.csv', index=False)

# %%
sales_df.to_csv('sales.csv', index=False)

# %%
orders_df.to_csv('orders.csv', index=False)

# %%
suppliers_df.to_csv('suppliers.csv', index=False)

# %% [markdown]
# ## Connecting Python to Sql server

# %%
import mysql.connector
from mysql.connector import connection
from mysql.connector import Error, errors

# %%
con = mysql.connector.connect(user = 'root',
                              host = '127.0.0.1',
                              password = 'Papon1999',
                              database='raksha_pipes')
Info = con.get_server_info()
print("Connected to MySQL Server version ", Info)
cursor = con.cursor()
# Out:
# Connected to MySQL Server version  8.0.36

# %%
from sqlalchemy import create_engine
import pymysql
# connection string and create engine
engine = create_engine('mysql+mysqldb://root:Papon1999@127.0.0.1:3306/raksha_pipes')

# %% [markdown]
# ## Table's data uploded to Mysql Server

# %%
products = pd.read_csv('products.csv')
products
# Out:
#     product_id product_name  price
# 0            1          not     16
# 1            2    religious     32
# 2            3         give     54
# 3            4       myself     42
# 4            5        level     86
# ..         ...          ...    ...
# 95          96           to     41
# 96          97       entire     74
# 97          98         just     41
# 98          99          art      7
# 99         100       effect     44
#
# [100 rows x 3 columns]

# %%
# Create Products table
cursor.execute("""
CREATE TABLE IF NOT EXISTS Products (
product_id INT PRIMARY KEY,
product_name VARCHAR(255),
price INT
)
""")
print("Products table created successfully")
# Out:
# Products table created successfully

# %%
# from sqlalchemy import text

# with engine.connect() as con:
#     connection.execute(Products.insert(), products)

# %%
# Insert data into Products table
products.to_sql('Products', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\Bibhakar\AppData\Local\Temp\ipykernel_17480\3515903034.py:2: UserWarning: The provided table name 'Products' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   products.to_sql('Products', con=engine, if_exists='append', index=False)
# 100

# %%
Customers = pd.read_csv('Customers.csv')
Customers
# Out:
#     customer_id       customer_name                         email gender  \
# 0             1         April Lewis     kaylacrawford@example.com      F
# 1             2       Hector Malone      abigailknapp@example.com      M
# 2             3       Ashley Potter           brian70@example.org      F
# 3             4       Lori Hamilton       natalieboyd@example.org      M
# 4             5    Jennifer Hopkins      jenniferbuck@example.com      M
# 5             6    Frederick Riddle        kaylaclark@example.org      M
# 6             7    Laura Montgomery          cassie81@example.net      F
# 7             8      Anthony Thomas            fsmith@example.com      M
# 8             9     Victoria Walter          pamela08@example.net      M
# 9            10          Eric Allen  hendersonkatelyn@example.org      M
# 10           11    Claudia Anderson       simmonslisa@example.com      M
# 11           12         Luke Oliver        jasongreen@example.net      F
# 12           13         Pamela Luna           coxkyle@example.com      M
# 13           14      Megan Carrillo        leebethany@example.com      M
# 14           15        Cynthia Wise        mschneider@example.com      F
# 15           16           Ann Scott           amber73@example.net      M
# 16           17     Donald Castillo           tammy96@example.net      M
# 17           18       Hannah Burton           caleb13@example.org      M
# 18           19       Xavier Bishop            cstein@example.org      M
# 19           20       Justin Parker         jeffrey92@example.com      M
# 20           21          Jenny Dean           ldodson@example.org      M
# 21           22         Gary Jacobs      wesleybarnes@example.org      F
# 22           23       Michael Stone   catherinehughes@example.net      M
# 23           24            David Yu       ortizandrew@example.net      M
# 24           25      Michael Barnes            erin43@example.org      M
# 25           26      Kenneth Medina             lhale@example.org      M
# 26           27        Tina Rodgers             ucole@example.com      M
# 27           28        Edward Hicks          fnichols@example.net      F
# 28           29    Cynthia Harrison      jensenjeremy@example.net      F
# 29           30        John Proctor         chelsea52@example.com      F
# 30           31          April Gray            ryan36@example.com      F
# 31           32      Jessica Cooper            seth29@example.com      F
# 32           33      Caroline Weber        trodriguez@example.org      F
# 33           34     Tina Montgomery            tina20@example.net      M
# 34           35        Jackson Choi   charlesmatthews@example.com      M
# 35           36  Jacqueline Parsons          monica10@example.org      F
# 36           37         Lori Taylor        hilldennis@example.org      F
# 37           38         Carrie Carr       stephanie00@example.com      F
# 38           39    Stephanie Jordan        kimberly08@example.org      F
# 39           40     Calvin Harrison          rodney55@example.org      M
# 40           41     Shawn Rodriguez   michaelmcdonald@example.net      M
# 41           42          Gary Clark        andrewrose@example.com      M
# 42           43         Kevin Duran         darrell97@example.com      M
# 43           44     William Johnson    jonathonmiller@example.org      F
# 44           45      Joel Armstrong         smithbrad@example.org      M
# 45           46     Karen Castaneda             qwolf@example.com      M
# 46           47       Louis Stewart      wrightronald@example.org      F
# 47           48        Tracy Pierce     dawnblackburn@example.org      F
# 48           49         James Moore           tracy68@example.net      M
# 49           50   Elizabeth Farrell     robertrodgers@example.org      M
#
#     product_id
# 0           36
# 1           71
# 2           72
# 3           37
# 4           41
# 5           19
# 6            3
# 7           91
# 8           67
# 9           46
# 10          85
# 11          36
# 12          35
# 13          95
# 14          33
# 15          32
# 16          24
# 17          93
# 18          87
# 19          97
# 20          11
# 21          65
# 22          30
# 23          73
# 24          28
# 25           7
# 26          24
# 27          55
# 28          99
# 29          52
# 30          13
# 31          19
# 32          14
# 33           8
# 34          50
# 35          66
# 36          20
# 37          28
# 38          81
# 39         100
# 40          73
# 41          54
# 42          44
# 43          77
# 44          93
# 45          86
# 46          59
# 47          34
# 48          49
# 49          73

# %%
# Create Customers table
cursor.execute("""
CREATE TABLE Customers (
    customer_id INT AUTO_INCREMENT PRIMARY KEY,
    customer_name VARCHAR(255),
    email VARCHAR(255),
    gender VARCHAR(10),
    product_id INT
)
""")
print("Customers table created successfully")
# Out:
# Customers table created successfully

# %%
# Insert data into Customers table
Customers.to_sql('Customers', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\Bibhakar\AppData\Local\Temp\ipykernel_17480\327209530.py:2: UserWarning: The provided table name 'Customers' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   Customers.to_sql('Customers', con=engine, if_exists='append', index=False)
# 50

# %%
Sales = pd.read_csv('Sales.csv')
Sales
# Out:
#      sale_id  product_id  customer_id  quantity  sale_amount
# 0          1          36           35         7         4172
# 1          2          57           24         4         8186
# 2          3          99            7         7         5884
# 3          4          32           34         6         3366
# 4          5          16           14        10         1526
# ..       ...         ...          ...       ...          ...
# 995      996          92            4         1         3712
# 996      997          94            8         9         8631
# 997      998          32            2         8         9945
# 998      999          19            1         1         4933
# 999     1000          42           21         5          847
#
# [1000 rows x 5 columns]

# %%
# Create Sales table
cursor.execute("""
CREATE TABLE Sales (
    sale_id INT PRIMARY KEY,
    product_id INT,
    customer_id INT,
    quantity INT,
    sale_amount INT,
    FOREIGN KEY (product_id) REFERENCES Products(product_id),
    FOREIGN KEY (customer_id) REFERENCES Customers(customer_id)
)
""")
print("Sales table created successfully")
# Out:
# Sales table created successfully

# %%
# Insert data into Sales table
Sales.to_sql('Sales', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\Bibhakar\AppData\Local\Temp\ipykernel_17480\690187135.py:2: UserWarning: The provided table name 'Sales' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   Sales.to_sql('Sales', con=engine, if_exists='append', index=False)
# 1000

# %%
Orders = pd.read_csv('Orders.csv')
Orders
# Out:
#      order_id  customer_id           order_date  total_amount     status  \
# 0           1           18  2024-04-19 14:52:05          8824    pending
# 1           2           50  2023-09-06 08:52:36          7698    shipped
# 2           3           40  2023-07-22 16:24:16          6185    shipped
# 3           4            4  2024-04-24 12:53:16          4777    pending
# 4           5            7  2024-01-19 14:40:22           988  delivered
# ..        ...          ...                  ...           ...        ...
# 495       496           35  2024-01-14 09:11:14          1698    pending
# 496       497            7  2024-04-15 22:41:16            29    shipped
# 497       498           39  2023-09-21 16:15:06          5328    pending
# 498       499           43  2023-10-16 03:25:10          2519    pending
# 499       500           48  2023-12-31 09:50:01          8322  delivered
#
#      product_id
# 0            77
# 1            22
# 2            38
# 3            44
# 4            61
# ..          ...
# 495          69
# 496          60
# 497          53
# 498          52
# 499          36
#
# [500 rows x 6 columns]

# %%
# Create Orders table
cursor.execute("""
CREATE TABLE Orders (
    order_id INT PRIMARY KEY,
    customer_id INT,
    order_date DATE,
    total_amount DECIMAL(10, 2),
    status VARCHAR(50),
    product_id INT
)
""")
print("Orders table created successfully")
# Out:
# Orders table created successfully

# %%
# Insert data into Orders table
Orders.to_sql('Orders', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\Bibhakar\AppData\Local\Temp\ipykernel_17480\1826284344.py:2: UserWarning: The provided table name 'Orders' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   Orders.to_sql('Orders', con=engine, if_exists='append', index=False)
# 500

# %%
Suppliers = pd.read_csv('Suppliers.csv')
Suppliers
# Out:
#     supplier_id                   supplier_name  contact_info  product_id
# 0             1        Hurst, Martinez and Ward    7796687997          31
# 1             2      Nguyen, Lyons and Caldwell    6866986669          11
# 2             3                    Thompson PLC    6896989777          49
# 3             4                     Perez Group    9886969888          40
# 4             5                       Evans Inc    8689696898           2
# 5             6                Brown-Harrington    8669778876          79
# 6             7                    Huff-Mcbride    8999977889          17
# 7             8          Lynn, Miller and Brock    7898798987          40
# 8             9  Gutierrez, Oconnor and Johnson    8888988698          56
# 9            10                 Rogers and Sons    8877786788          68
# 10           11                     Shelton Inc    7887696679          91
# 11           12    Leonard, Serrano and Kennedy    8977678968          97
# 12           13                 Stewart-Fischer    6769966777          10
# 13           14                      Luna Group    6688866797          96
# 14           15                    Hunter Group    7866778668          72
# 15           16                     Levy-Romero    7788677878          94
# 16           17                       Black PLC    6679887996          56
# 17           18                      Monroe Ltd    8686697787          25
# 18           19      Pugh, Gonzalez and Pearson    7677999799          49
# 19           20     Gallegos, Hurst and Ferrell    7868987679          17

# %%
 # Create Suppliers table
cursor.execute("""
CREATE TABLE Suppliers (
    supplier_id INT PRIMARY KEY,
    supplier_name VARCHAR(255),
    contact_info VARCHAR(255),
    product_id INT
)
""")
print("Suppliers table created successfully")
# Out:
# Suppliers table created successfully

# %%
# Insert data into Suppliers table
Suppliers.to_sql('Suppliers', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\Bibhakar\AppData\Local\Temp\ipykernel_17480\2367933318.py:2: UserWarning: The provided table name 'Suppliers' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   Suppliers.to_sql('Suppliers', con=engine, if_exists='append', index=False)
# 20

# %%
cursor.close()
con.close()
print("MySQL connection is closed")
# Out:
# MySQL connection is closed
